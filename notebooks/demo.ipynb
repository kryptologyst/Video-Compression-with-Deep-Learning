# %% [markdown]
# # Video Compression with Deep Learning - Demo Notebook
#
# This notebook demonstrates the video compression capabilities of our deep learning models.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.append('src')

import torch
import numpy as np
import matplotlib.pyplot as plt
from models.video_compressor import VideoAutoencoder, TemporalVideoAutoencoder
from data.video_dataset import create_sample_video
from utils.device import get_device, set_seed
from utils.metrics import calculate_psnr, calculate_ssim

# Set random seed for reproducibility
set_seed(42)

print(f"Using device: {get_device()}")
